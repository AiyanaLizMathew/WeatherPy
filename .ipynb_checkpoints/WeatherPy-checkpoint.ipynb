# %% [markdown]
# # WeatherPY

# %% [markdown]
# ### Analysis on WeatherPY
# -  The plot on Latitude vs Temperature shows that the temperature is highest at the equator and lowest at the poles.
# -  The humidity at the equator is in the range from 50%-100%. Howeever, the trends does not change based on the latitude.
# -  There seems to be no co-relation of cloudliness with respect to the latitude.
# -  The windspeed for most cities fall under 25mph and there seems to be no trend on the windspeed with respect to the latitude.

# %%
# Dependencies
import random
import requests as req

import pandas as pd
import numpy as np

import matplotlib.pyplot as plt

from citipy import citipy
import openweathermapy as owm

#To get the current date
import datetime
now = datetime.datetime.now()

# %%
# Create a settings object with your API key and preferred units
api_key = "4af76c79df8d11f6295bc8323877e2e5"
#Setting the units to imperial to get Fahrenheit reading
settings = {"units": "imperial", "appid": api_key}

# %% [markdown]
# ## Generate Cities List

# %%
# Latitude ranges from -90 to 90 and Longitude ranges from -180 to 180
lat = list(np.arange(-90,90.01,0.01))
long = list(np.arange(-180,180.01,0.01))

# Setting Latitude and Longitude to ramdomly pick co-ordinates.
lat_samples=random.sample(lat,2000)
long_samples=random.sample(long,2000)

# Creating a dataframe from the randomly sample Latitude and Longitude
cities_DF=pd.DataFrame({"Latitude":lat_samples,"Longitude":long_samples})

#Creating new columns City and Country for storing the details corresponding to the co-ordinates
cities_DF["City"]=""
cities_DF["Country"]=""

# Finding the city and the country code corresponding to the Latitude and Longitude
for index,row in cities_DF.iterrows():
    city=citipy.nearest_city(row["Latitude"], row["Longitude"])
    cities_DF.set_value(index, "City", city.city_name)
    cities_DF.set_value(index, "Country", city.country_code)

# Dropping the Latitude and Longitude as they are values of the nearest city and not the excat co-ordinates of the city
cities_DF=cities_DF.drop(cities_DF.columns[[0, 1]], axis=1)

# Deleting duplicate values from the list of cities and keeping only the first
cities_DF=cities_DF.drop_duplicates(['City'], keep='first')

# Randomly sampling a list of 700 cities 
cities_DF=cities_DF.sample(n=700)

# Resetting the index of the cities list
cities_DF=cities_DF.reset_index(drop=True)

cities_DF.head()
# Out:
#                City Country
# 0      uusikaupunki      fi
# 1          tarudant      ma
# 2          iracoubo      gf
# 3            norsup      vu
# 4  praia da vitoria      pt

# %% [markdown]
# ## Perform API Calls

# %%
# Get data for each city in cities_DF
weather_data = []

url="https://api.openweathermap.org/data/2.5/weather?appid=" + api_key + "&units=imperial&q="

print("\nBeginning Data Retrieval\n-----------------------------")
#Get the response from OpenWeatherMapY and storing the response into weather_data if response is found
for index,row in cities_DF.iterrows():  
    print("\nProcessing record %s|%s,%s"%((index+1),row["City"],row["Country"]))
    print("\n"+url+"%s,%s"%(row["City"].replace(" ","+"),row["Country"]))
    try:
        response = owm.get_current("%s,%s"%(row["City"],row["Country"]), **settings)
        # Appending the response to the weather_Data
        weather_data.append(response)
    except:
        print("\n\033[1;31mCity not found. Skipping...\033[1;30m")

print("\n-----------------------------\nData Retrieval Complete\n-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
#
# Processing record 1|uusikaupunki,fi
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=uusikaupunki,fi
#
# Processing record 2|tarudant,ma
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=tarudant,ma
#
# City not found. Skipping...
#
# Processing record 3|iracoubo,gf
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=iracoubo,gf
#
# Processing record 4|norsup,vu
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=norsup,vu
#
# Processing record 5|praia da vitoria,pt
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=praia+da+vitoria,pt
#
# Processing record 6|vila franca do campo,pt
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=vila+franca+do+campo,pt
#
# Processing record 7|talcahuano,cl
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=talcahuano,cl
#
# Processing record 8|marv dasht,ir
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=marv+dasht,ir
#
# City not found. Skipping...
#
# Processing record 9|cherskiy,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=cherskiy,ru
#
# Processing record 10|scarborough,tt
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=scarborough,tt
#
# Processing record 11|balkanabat,tm
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=balkanabat,tm
#
# Processing record 12|chorozinho,br
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=chorozinho,br
#
# Processing record 13|olafsvik,is
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=olafsvik,is
#
# City not found. Skipping...
#
# Processing record 14|saint-joseph,re
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=saint-joseph,re
#
# Processing record 15|beyneu,kz
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=beyneu,kz
#
# Processing record 16|port alfred,za
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=port+alfred,za
#
# Processing record 17|kunashak,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=kunashak,ru
#
# Processing record 18|osypenko,ua
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=osypenko,ua
#
# Processing record 19|adoni,in
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=adoni,in
#
# Processing record 20|bilibino,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=bilibino,ru
#
# Processing record 21|sodertalje,se
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=sodertalje,se
#
# City not found. Skipping...
#
# Processing record 22|galiwinku,au
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=galiwinku,au
#
# City not found. Skipping...
#
# Processing record 23|rawah,iq
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=rawah,iq
#
# Processing record 24|farafangana,mg
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=farafangana,mg
#
# Processing record 25|turkan,az
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=turkan,az
#
# Processing record 26|berlevag,no
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=berlevag,no
#
# Processing record 27|belmonte,br
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=belmonte,br
#
# Processing record 28|hami,cn
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=hami,cn
#
# Processing record 29|cankuzo,bi
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=cankuzo,bi
#
# Processing record 30|qaanaaq,gl
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=qaanaaq,gl
#
# Processing record 31|aklavik,ca
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=aklavik,ca
#
# Processing record 32|kifri,iq
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=kifri,iq
#
# Processing record 33|batagay-alyta,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=batagay-alyta,ru
#
# Processing record 34|saskylakh,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=saskylakh,ru
#
# Processing record 35|hoa binh,vn
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=hoa+binh,vn
#
# Processing record 36|azuaga,es
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=azuaga,es
#
# Processing record 37|bima,id
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=bima,id
#
# Processing record 38|zinder,ne
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=zinder,ne
#
# Processing record 39|nyurba,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=nyurba,ru
#
# Processing record 40|machilipatnam,in
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=machilipatnam,in
#
# Processing record 41|mahanoro,mg
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=mahanoro,mg
#
# Processing record 42|bathsheba,bb
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=bathsheba,bb
#
# Processing record 43|beidao,cn
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=beidao,cn
#
# Processing record 44|aginskoye,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=aginskoye,ru
#
# Processing record 45|dutse,ng
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=dutse,ng
#
# Processing record 46|miri,my
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=miri,my
#
# Processing record 47|eyl,so
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=eyl,so
#
# Processing record 48|sangmelima,cm
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=sangmelima,cm
#
# Processing record 49|north bend,us
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=north+bend,us
#
# Processing record 50|liwan,ph
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=liwan,ph
#
# Processing record 51|khani,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=khani,ru
#
# City not found. Skipping...
#
# Processing record 52|amboasary,mg
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=amboasary,mg
#
# Processing record 53|kamyshlov,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=kamyshlov,ru
# Processing record 54|ribeira grande,pt
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=ribeira+grande,pt
#
# Processing record 55|taltal,cl
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=taltal,cl
#
# Processing record 56|tarauaca,br
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=tarauaca,br
#
# Processing record 57|nunkini,mx
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=nunkini,mx
#
# Processing record 58|broome,au
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=broome,au
#
# Processing record 59|broken hill,au
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=broken+hill,au
#
# Processing record 60|myitkyina,mm
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=myitkyina,mm
#
# Processing record 61|xiongzhou,cn
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=xiongzhou,cn
#
# Processing record 62|saleaula,ws
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=saleaula,ws
#
# City not found. Skipping...
#
# Processing record 63|viesite,lv
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=viesite,lv
#
# Processing record 64|bontang,id
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=bontang,id
#
# Processing record 65|ilulissat,gl
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=ilulissat,gl
#
# Processing record 66|san andres,co
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=san+andres,co
#
# Processing record 67|skibbereen,ie
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=skibbereen,ie
#
# Processing record 68|port elizabeth,za
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=port+elizabeth,za
#
# Processing record 69|camacupa,ao
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=camacupa,ao
#
# Processing record 70|catemaco,mx
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=catemaco,mx
#
# Processing record 71|mgandu,tz
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=mgandu,tz
#
# Processing record 72|ossora,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=ossora,ru
#
# Processing record 73|evensk,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=evensk,ru
#
# Processing record 74|tidore,id
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=tidore,id
#
# City not found. Skipping...
#
# Processing record 75|xuddur,so
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=xuddur,so
#
# Processing record 76|hibbing,us
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=hibbing,us
#
# Processing record 77|east london,za
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=east+london,za
#
# Processing record 78|dingle,ie
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=dingle,ie
#
# Processing record 79|qostanay,kz
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=qostanay,kz
#
# Processing record 80|oktyabrskoye,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=oktyabrskoye,ru
#
# Processing record 81|otane,nz
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=otane,nz
#
# Processing record 82|college,us
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=college,us
#
# Processing record 83|meulaboh,id
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=meulaboh,id
#
# Processing record 84|kahului,us
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=kahului,us
#
# Processing record 85|gaoua,bf
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=gaoua,bf
#
# Processing record 86|kem,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=kem,ru
#
# Processing record 87|mys shmidta,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=mys+shmidta,ru
#
# City not found. Skipping...
#
# Processing record 88|hovd,mn
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=hovd,mn
#
# Processing record 89|honningsvag,no
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=honningsvag,no
#
# Processing record 90|hammerfest,no
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=hammerfest,no
#
# Processing record 91|saint-pierre,pm
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=saint-pierre,pm
#
# Processing record 92|husavik,is
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=husavik,is
#
# Processing record 93|pacific grove,us
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=pacific+grove,us
#
# Processing record 94|atuona,pf
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=atuona,pf
#
# Processing record 95|grenada,us
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=grenada,us
#
# Processing record 96|windsor,ca
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=windsor,ca
#
# Processing record 97|hokitika,nz
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=hokitika,nz
#
# Processing record 98|metsovon,gr
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=metsovon,gr
#
# City not found. Skipping...
#
# Processing record 99|jumla,np
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=jumla,np
#
# Processing record 100|roseland,us
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=roseland,us
#
# Processing record 101|jiaonan,cn
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=jiaonan,cn
#
# Processing record 102|turukhansk,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=turukhansk,ru
#
# Processing record 103|alofi,nu
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=alofi,nu
#
# Processing record 104|ust-tsilma,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=ust-tsilma,ru
#
# Processing record 105|narsaq,gl
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=narsaq,gl
#
# Processing record 106|coihaique,cl
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=coihaique,cl
#
# Processing record 107|emerald,au
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=emerald,au
# Processing record 108|nome,us
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=nome,us
#
# Processing record 109|puerto baquerizo moreno,ec
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=puerto+baquerizo+moreno,ec
#
# Processing record 110|namatanai,pg
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=namatanai,pg
#
# Processing record 111|dikson,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=dikson,ru
#
# Processing record 112|warangal,in
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=warangal,in
#
# Processing record 113|san quintin,mx
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=san+quintin,mx
#
# Processing record 114|mbanza-ngungu,cd
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=mbanza-ngungu,cd
#
# Processing record 115|saint george,bm
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=saint+george,bm
#
# Processing record 116|iquique,cl
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=iquique,cl
#
# Processing record 117|huancabamba,pe
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=huancabamba,pe
#
# Processing record 118|waingapu,id
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=waingapu,id
#
# Processing record 119|port hardy,ca
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=port+hardy,ca
#
# Processing record 120|gawler,au
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=gawler,au
#
# Processing record 121|teknaf,bd
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=teknaf,bd
#
# Processing record 122|puerto ayora,ec
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=puerto+ayora,ec
#
# Processing record 123|andenes,no
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=andenes,no
#
# Processing record 124|hilo,us
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=hilo,us
#
# Processing record 125|ivybridge,gb
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=ivybridge,gb
#
# Processing record 126|killybegs,ie
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=killybegs,ie
#
# Processing record 127|tommot,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=tommot,ru
#
# Processing record 128|provideniya,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=provideniya,ru
#
# Processing record 129|bereda,so
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=bereda,so
#
# City not found. Skipping...
#
# Processing record 130|lima,pe
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=lima,pe
#
# Processing record 131|raga,sd
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=raga,sd
#
# City not found. Skipping...
#
# Processing record 132|longyearbyen,sj
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=longyearbyen,sj
#
# Processing record 133|suure-jaani,ee
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=suure-jaani,ee
#
# Processing record 134|alice springs,au
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=alice+springs,au
#
# Processing record 135|chamba,in
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=chamba,in
#
# Processing record 136|khunzakh,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=khunzakh,ru
#
# Processing record 137|kungurtug,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=kungurtug,ru
#
# Processing record 138|half moon bay,us
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=half+moon+bay,us
#
# Processing record 139|tasiilaq,gl
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=tasiilaq,gl
#
# Processing record 140|bibiani,gh
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=bibiani,gh
#
# Processing record 141|avera,pf
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=avera,pf
#
# City not found. Skipping...
#
# Processing record 142|tigil,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=tigil,ru
#
# Processing record 143|illoqqortoormiut,gl
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=illoqqortoormiut,gl
#
# City not found. Skipping...
#
# Processing record 144|taoudenni,ml
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=taoudenni,ml
#
# Processing record 145|kerrville,us
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=kerrville,us
#
# Processing record 146|bluff,nz
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=bluff,nz
#
# Processing record 147|suez,eg
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=suez,eg
#
# Processing record 148|manutuke,nz
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=manutuke,nz
#
# Processing record 149|ahipara,nz
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=ahipara,nz
#
# Processing record 150|khorixas,na
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=khorixas,na
#
# Processing record 151|marawi,sd
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=marawi,sd
#
# Processing record 152|honiara,sb
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=honiara,sb
#
# Processing record 153|general pico,ar
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=general+pico,ar
#
# Processing record 154|nalut,ly
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=nalut,ly
#
# Processing record 155|mattru,sl
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=mattru,sl
#
# City not found. Skipping...
#
# Processing record 156|digapahandi,in
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=digapahandi,in
#
# Processing record 157|wana,pk
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=wana,pk
#
# Processing record 158|malakal,sd
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=malakal,sd
#
# City not found. Skipping...
#
# Processing record 159|oranjemund,na
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=oranjemund,na
# Processing record 160|pisco,pe
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=pisco,pe
#
# Processing record 161|palu,id
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=palu,id
#
# Processing record 162|tuktoyaktuk,ca
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=tuktoyaktuk,ca
#
# Processing record 163|eisenerz,at
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=eisenerz,at
#
# Processing record 164|high level,ca
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=high+level,ca
#
# Processing record 165|caluquembe,ao
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=caluquembe,ao
#
# Processing record 166|labuhan,id
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=labuhan,id
#
# Processing record 167|umm kaddadah,sd
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=umm+kaddadah,sd
#
# Processing record 168|vieux-habitants,gp
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=vieux-habitants,gp
#
# Processing record 169|kutum,sd
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=kutum,sd
#
# Processing record 170|lazaro cardenas,mx
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=lazaro+cardenas,mx
#
# Processing record 171|seddon,nz
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=seddon,nz
#
# City not found. Skipping...
#
# Processing record 172|karaul,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=karaul,ru
#
# City not found. Skipping...
#
# Processing record 173|tres lagoas,br
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=tres+lagoas,br
#
# Processing record 174|mozhga,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=mozhga,ru
#
# Processing record 175|port blair,in
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=port+blair,in
#
# Processing record 176|antipovka,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=antipovka,ru
#
# Processing record 177|kralendijk,an
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=kralendijk,an
#
# City not found. Skipping...
#
# Processing record 178|krasnovishersk,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=krasnovishersk,ru
#
# Processing record 179|prainha,br
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=prainha,br
#
# Processing record 180|kondinskoye,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=kondinskoye,ru
#
# Processing record 181|ambilobe,mg
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=ambilobe,mg
#
# Processing record 182|rungata,ki
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=rungata,ki
#
# City not found. Skipping...
#
# Processing record 183|ariquemes,br
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=ariquemes,br
#
# Processing record 184|svetlogorsk,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=svetlogorsk,ru
#
# Processing record 185|dudinka,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=dudinka,ru
#
# Processing record 186|hamilton,bm
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=hamilton,bm
#
# Processing record 187|robstown,us
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=robstown,us
#
# Processing record 188|minna,ng
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=minna,ng
#
# Processing record 189|punta arenas,cl
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=punta+arenas,cl
#
# Processing record 190|leh,in
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=leh,in
#
# Processing record 191|mahebourg,mu
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=mahebourg,mu
#
# Processing record 192|omboue,ga
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=omboue,ga
#
# Processing record 193|ugoofaaru,mv
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=ugoofaaru,mv
#
# Processing record 194|ermioni,gr
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=ermioni,gr
#
# Processing record 195|clyde river,ca
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=clyde+river,ca
#
# Processing record 196|muli,mv
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=muli,mv
#
# Processing record 197|nishihara,jp
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=nishihara,jp
#
# Processing record 198|sistranda,no
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=sistranda,no
#
# Processing record 199|grand gaube,mu
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=grand+gaube,mu
#
# Processing record 200|sao felix do xingu,br
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=sao+felix+do+xingu,br
#
# Processing record 201|newport,us
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=newport,us
#
# Processing record 202|umm lajj,sa
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=umm+lajj,sa
#
# Processing record 203|ust-kulom,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=ust-kulom,ru
#
# Processing record 204|alexandria,eg
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=alexandria,eg
#
# Processing record 205|asau,tv
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=asau,tv
#
# City not found. Skipping...
#
# Processing record 206|abha,sa
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=abha,sa
#
# Processing record 207|sompeta,in
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=sompeta,in
#
# Processing record 208|barranca,pe
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=barranca,pe
#
# Processing record 209|geresk,af
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=geresk,af
#
# City not found. Skipping...
#
# Processing record 210|sola,vu
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=sola,vu
#
# Processing record 211|guangyuan,cn
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=guangyuan,cn
# Processing record 212|busselton,au
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=busselton,au
#
# Processing record 213|onega,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=onega,ru
#
# Processing record 214|muisne,ec
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=muisne,ec
#
# Processing record 215|algiers,dz
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=algiers,dz
#
# Processing record 216|lodwar,ke
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=lodwar,ke
#
# Processing record 217|fevralsk,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=fevralsk,ru
#
# City not found. Skipping...
#
# Processing record 218|bengkulu,id
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=bengkulu,id
#
# Processing record 219|bobingen,de
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=bobingen,de
#
# Processing record 220|alotau,pg
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=alotau,pg
#
# City not found. Skipping...
#
# Processing record 221|nemuro,jp
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=nemuro,jp
#
# Processing record 222|waipawa,nz
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=waipawa,nz
#
# Processing record 223|talnakh,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=talnakh,ru
#
# Processing record 224|puerto escondido,mx
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=puerto+escondido,mx
#
# Processing record 225|sao jose da coroa grande,br
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=sao+jose+da+coroa+grande,br
#
# Processing record 226|puksoozero,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=puksoozero,ru
#
# Processing record 227|halalo,wf
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=halalo,wf
#
# City not found. Skipping...
#
# Processing record 228|upernavik,gl
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=upernavik,gl
#
# Processing record 229|mungeli,in
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=mungeli,in
#
# Processing record 230|rockport,us
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=rockport,us
#
# Processing record 231|saint-philippe,re
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=saint-philippe,re
#
# Processing record 232|margate,za
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=margate,za
#
# Processing record 233|auki,sb
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=auki,sb
#
# Processing record 234|lexington park,us
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=lexington+park,us
#
# Processing record 235|poum,nc
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=poum,nc
#
# Processing record 236|soyalo,mx
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=soyalo,mx
#
# Processing record 237|ola,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=ola,ru
#
# Processing record 238|tura,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=tura,ru
#
# Processing record 239|komsomolskiy,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=komsomolskiy,ru
#
# Processing record 240|bodden town,ky
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=bodden+town,ky
#
# Processing record 241|beaver dam,us
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=beaver+dam,us
#
# Processing record 242|popondetta,pg
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=popondetta,pg
#
# Processing record 243|williams lake,ca
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=williams+lake,ca
#
# Processing record 244|baboua,cf
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=baboua,cf
#
# City not found. Skipping...
#
# Processing record 245|moron,mn
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=moron,mn
#
# Processing record 246|keflavik,is
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=keflavik,is
#
# Processing record 247|charters towers,au
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=charters+towers,au
#
# Processing record 248|klaksvik,fo
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=klaksvik,fo
#
# Processing record 249|lagoa,pt
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=lagoa,pt
#
# Processing record 250|tezu,in
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=tezu,in
#
# Processing record 251|plainview,us
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=plainview,us
#
# Processing record 252|goundam,ml
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=goundam,ml
#
# Processing record 253|sao joao da barra,br
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=sao+joao+da+barra,br
#
# Processing record 254|cabo san lucas,mx
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=cabo+san+lucas,mx
#
# Processing record 255|fairbanks,us
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=fairbanks,us
#
# Processing record 256|cassilandia,br
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=cassilandia,br
#
# Processing record 257|khatanga,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=khatanga,ru
#
# Processing record 258|rosarito,mx
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=rosarito,mx
#
# Processing record 259|nova odesa,ua
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=nova+odesa,ua
#
# Processing record 260|bambous virieux,mu
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=bambous+virieux,mu
#
# Processing record 261|novocheboksarsk,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=novocheboksarsk,ru
#
# Processing record 262|santa cruz,cr
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=santa+cruz,cr
#
# Processing record 263|ketchikan,us
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=ketchikan,us
#
# Processing record 264|mendoza,ar
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=mendoza,ar
# Processing record 265|ilhabela,br
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=ilhabela,br
#
# Processing record 266|yar-sale,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=yar-sale,ru
#
# Processing record 267|rikitea,pf
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=rikitea,pf
#
# Processing record 268|taywarah,af
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=taywarah,af
#
# Processing record 269|ancud,cl
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=ancud,cl
#
# Processing record 270|el vigia,ve
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=el+vigia,ve
#
# Processing record 271|ust-kamchatsk,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=ust-kamchatsk,ru
#
# City not found. Skipping...
#
# Processing record 272|tumannyy,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=tumannyy,ru
#
# City not found. Skipping...
#
# Processing record 273|dzhebariki-khaya,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=dzhebariki-khaya,ru
#
# Processing record 274|bonthe,sl
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=bonthe,sl
#
# Processing record 275|jalu,ly
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=jalu,ly
#
# City not found. Skipping...
#
# Processing record 276|mweka,cd
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=mweka,cd
#
# Processing record 277|lompoc,us
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=lompoc,us
#
# Processing record 278|pokhara,np
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=pokhara,np
#
# Processing record 279|sorland,no
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=sorland,no
#
# Processing record 280|formosa do rio preto,br
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=formosa+do+rio+preto,br
#
# Processing record 281|otradnoye,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=4af76c79df8d11f6295bc8323877e2e5&units=imperial&q=otradnoye,ru

# %% [markdown]
# ## Weather DataFrame

# %%
# Create an "extracts" object to get the various parameter required to form the weather data table
summary = ["name","sys.country","dt","coord.lat", "coord.lon","main.temp_max","main.humidity","wind.speed","clouds.all"]

# Create a Pandas DataFrame with the results
data = [response(*summary) for response in weather_data]
column_names = ["City","Country","Date","Latitude", "Longitude","Temperature","Humidity","Wind speed","Cloudliness"]
weather_data = pd.DataFrame(data, columns=column_names)

weather_data.head()

# %%
#Save the result to a csv file
weather_data.to_csv("Weather_Data.csv")
# Count of the data in the dataframe
weather_data.count()

# %% [markdown]
# ## Latitude vs Temperature Plot

# %%
# Latitude vs Max. Temperature(F)
plt.scatter(x=weather_data["Latitude"],y=weather_data["Temperature"],facecolors="navy",edgecolors="black")
plt.xlabel("Latitude")
plt.ylabel("Max. Temperature(°F)")
plt.xlim(-90,90)
plt.title("City Latitude vs Max.Temperature(°F) (%s/%s/%s)"%(now.month,now.day,now.year))
plt.grid(True)
plt.savefig("City Latitude vs Temperature.jpeg")
plt.show()

# %% [markdown]
# ## Latitude vs Humidity Plot

# %%
# Latitude vs Humidity

plt.scatter(x=weather_data["Latitude"],y=weather_data["Humidity"],facecolors="navy",edgecolors="black")
plt.xlabel("Latitude")
plt.ylabel("Humidity(%)")
plt.xlim(-90,90)
plt.title("City Latitude vs Humidity (%s/%s/%s)"%(now.month,now.day,now.year))
plt.grid(True)
plt.savefig("City Latitude vs Humidity.jpeg")
plt.show()

# %% [markdown]
# ## Latitude vs Cloudliness

# %%
# Latitude vs Cloudliness  

plt.scatter(x=weather_data["Latitude"],y=weather_data["Cloudliness"],facecolors="navy",edgecolors="black")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness(%)")
plt.xlim(-90,90)
plt.title("City Latitude vs Cloudiness (%s/%s/%s)"%(now.month,now.day,now.year))
plt.grid(True)
plt.savefig("City Latitude vs Cloudiness.jpeg")
plt.show()

# %% [markdown]
# ## Latitude vs Wind Speed

# %%
# Latitude vs Wind Speed  

plt.scatter(x=weather_data["Latitude"],y=weather_data["Wind speed"],facecolors="navy",edgecolors="black")
plt.xlabel("Latitude")
plt.ylabel("Wind speed(mph)")
plt.xlim(-90,90)
plt.title("City Latitude vs Wind speed (%s/%s/%s)"%(now.month,now.day,now.year))
plt.grid(True)
plt.savefig("City Latitude vs Wind speed.jpeg")
plt.show()
